# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
## Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "schools_complete.csv"
student_data_to_load = "students_complete.csv"

# Read School and Student Data File and store into Pandas Data Frames
school_data = pd.read_csv(school_data_to_load)
school_data.head()

# to check the number of schools
#school_data.tail()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
# Read School and Student Data File and store into Pandas Data Frames
student_data = pd.read_csv(student_data_to_load)
student_data.head()

# to check the number of students
#student_data.tail()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
# Combine the data into a single dataset
school_data_complete = pd.merge(student_data, school_data, how='left', on=['school_name', 'school_name'])
school_data_complete.head(100)
# Out:
#     Student ID         student_name gender grade        school_name  \
# 0            0         Paul Bradley      M   9th  Huang High School
# 1            1         Victor Smith      M  12th  Huang High School
# 2            2      Kevin Rodriguez      M  12th  Huang High School
# 3            3    Dr. Richard Scott      M  12th  Huang High School
# 4            4           Bonnie Ray      F   9th  Huang High School
# ..         ...                  ...    ...   ...                ...
# 95          95       Kevin Martinez      M  11th  Huang High School
# 96          96        Jessica Smith      F   9th  Huang High School
# 97          97        Dawn Trujillo      F  11th  Huang High School
# 98          98  Virginia Ramirez MD      F  10th  Huang High School
# 99          99       Marc Hernandez      M  10th  Huang High School
#
#     reading_score  math_score  School ID      type  size   budget
# 0              66          79          0  District  2917  1910635
# ...

# %%
#  Calculate the total number of schools - ex: from Extra Content Stu projects part 1 activity
#Print with formating sting using f" 
total_number_school = len(school_data)
total_number_school
# Out:
# 15

# %%
# Calculate the total number of students
total_number_students = len(student_data)
total_number_students
# Out:
# 39170

# %%
# Calculate the total budget
total_budget = school_data["budget"].sum()
total_budget
# Out:
# 24649428

# %%
# Calculate the average math score - #### USE MEAN FOR THE AVERAGE ###
avg_math_score = student_data["math_score"].mean()
avg_math_score
# Out:
# 78.98537145774827

# %%
# Calculate the average reading score - ### USE MEAN FOR THE AVERAGE ###
avg_reading_score = student_data["reading_score"].mean()
avg_reading_score
# Out:
# 81.87784018381414

# %%
#* Calculate the percentage of students with a passing math score (70 or greater)
#percent of studenents = avg math score/total number of students * 100
# can't use print(students passing math) because this needs to use a f string  ex:print(f" Total: {total_gender}\n Male: {male}\n Female: {female}\n non_specfic: {non_gender_specific}") 
students_passing_math = school_data_complete.loc[school_data_complete["math_score"] >= 70]
total_students_passing_math = students_passing_math["Student ID"].count()
per_passing_math = (total_students_passing_math/total_number_students) * 100

print(f"{per_passing_math:}%")
# Out:
# 74.9808526933878%

# %%
# Calculate the percentage of students with a passing reading score (70 or greater)
students_passing_reading = school_data_complete.loc[school_data_complete["reading_score"] >= 70]
total_students_passing_reading = students_passing_reading["Student ID"].nunique()
per_passing_reading = (total_students_passing_reading/total_number_students) * 100

print(f"{per_passing_reading:}%")
# Out:
# 85.80546336482001%

# %%
# Calculate the overall passing rate (overall average score), i.e. (avg. math score + avg. reading score)/2
overall_passing_rate = (avg_math_score + avg_reading_score)/2
overall_passing_rate
# Out:
# 80.43160582078121

# %%
#Create a dataframe to hold the above results - EXAMPLE FROM STU PROJECTS PART 1 - 
#Total # of Schools
#Total # of Students
# Total Budget
# Average Math & reading score
# % Passing Math
# % Passing Reading 
#Overall Passing Rate
# Clean formatting before outputting spreadsheet - "{0:,.6f}%"
District_Summary = pd.DataFrame({
    "Total Schools":[total_number_school],
    "Total Students": f"{total_number_students:,}",
    "Total Budget": f"${total_budget:,}",
    "Average Math Score": f"{avg_math_score:.6f}",
    "Average Reading Score":f"{avg_reading_score:.6f}",
    "% Passing Math": f"{per_passing_math:.6f}%",
    "% Passing Reading": f"{per_passing_reading:.6f}%",
    "Overall Passing Rate": f"{overall_passing_rate:.6f}%"
}) 
District_Summary
# Out:
#    Total Schools Total Students Total Budget Average Math Score  \
# 0             15         39,170  $24,649,428          78.985371
#
#   Average Reading Score % Passing Math % Passing Reading Overall Passing Rate
# 0             81.877840     74.980853%        85.805463%           80.431606%

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the overall passing rate (overall average score), i.e. (avg. math score + avg. reading score)/2
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)
#
# * Create a dataframe to hold the above results

# %%
# - EXPLORING PANDAS ACTIVITY IN SUPPLEMENTAL PANDAS 
#Create dateframe for school info 
# Combine the data into a single dataset
school_data_combined_df = pd.merge(student_data, school_data, how='left', on=['school_name', 'school_name'])
school_data_combined_df
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# ...

# %%
# EXPLORING PANDAS ACTIVITY IN SUPPLEMENTAL PANDAS 
#School Name
#grouped_df = original_df.groupby('column1')
#Pull data from "school_name" values
grouped_school_data = school_data_combined_df.groupby(['school_name', 'type']).count()['Student ID']
grouped_school_data
#print(f"School Name: {grouped_school_data}")
# Out:
#               school_name      type  Student ID
# 0      Bailey High School  District        4976
# 1     Cabrera High School   Charter        1858
# 2    Figueroa High School  District        2949
# 3        Ford High School  District        2739
# 4     Griffin High School   Charter        1468
# 5   Hernandez High School  District        4635
# 6      Holden High School   Charter         427
# 7       Huang High School  District        2917
# 8     Johnson High School  District        4761
# 9        Pena High School   Charter         962
# 10  Rodriguez High School  District        3999
# 11    Shelton High School   Charter        1761
# 12     Thomas High School   Charter        1635
# 13     Wilson High School   Charter        2283
# 14     Wright High School   Charter        1800

# %%
#School Type
summary_school_type = grouped_school_data.groupby(['school_name', 'type']).count()
summary_school_type
# Out:
#                                 Student ID
# school_name           type
# Bailey High School    District           1
# Cabrera High School   Charter            1
# Figueroa High School  District           1
# Ford High School      District           1
# Griffin High School   Charter            1
# Hernandez High School District           1
# Holden High School    Charter            1
# Huang High School     District           1
# Johnson High School   District           1
# Pena High School      Charter            1
# Rodriguez High School District           1
# Shelton High School   Charter            1
# Thomas High School    Charter            1
# Wilson High School    Charter            1
# Wright High School    Charter            1

# %%
# # Have to combine the two data sets into a single dataset to do the school summary columns
school_summary_df2 = pd.merge(grouped_school_data, summary_school_type, how="left", on=['Student ID', 'school_name', 'type'])
school_summary_df2
# Out:
#               school_name      type  Student ID
# 0      Bailey High School  District        4976
# 1     Cabrera High School   Charter        1858
# 2    Figueroa High School  District        2949
# 3        Ford High School  District        2739
# 4     Griffin High School   Charter        1468
# 5   Hernandez High School  District        4635
# 6      Holden High School   Charter         427
# 7       Huang High School  District        2917
# 8     Johnson High School  District        4761
# 9        Pena High School   Charter         962
# 10  Rodriguez High School  District        3999
# 11    Shelton High School   Charter        1761
# 12     Thomas High School   Charter        1635
# 13     Wilson High School   Charter        2283
# 14     Wright High School   Charter        1800

# %%
# Summarize the total number of students
summary_total_number_students = school_data_combined_df.groupby(["school_name"]).count()["size"]
summary_total_number_students
# Out:
# school_name
# Bailey High School       4976
# Cabrera High School      1858
# Figueroa High School     2949
# Ford High School         2739
# Griffin High School      1468
# Hernandez High School    4635
# Holden High School        427
# Huang High School        2917
# Johnson High School      4761
# Pena High School          962
# Rodriguez High School    3999
# Shelton High School      1761
# Thomas High School       1635
# Wilson High School       2283
# Wright High School       1800
# Name: size, dtype: int64

# %%
#Summary for total school budget
summary_total_school_budget = school_data_combined_df.groupby(["school_name"]).mean()["budget"]
summary_total_school_budget
# Out:
# school_name
# Bailey High School       3124928.0
# Cabrera High School      1081356.0
# Figueroa High School     1884411.0
# Ford High School         1763916.0
# Griffin High School       917500.0
# Hernandez High School    3022020.0
# Holden High School        248087.0
# Huang High School        1910635.0
# Johnson High School      3094650.0
# Pena High School          585858.0
# Rodriguez High School    2547363.0
# Shelton High School      1056600.0
# Thomas High School       1043130.0
# Wilson High School       1319574.0
# Wright High School       1049400.0
# Name: budget, dtype: float64

# %%
# Have to combine the two data sets into a single dataset to do get school summary
school_summary_df2 = pd.merge(summary_total_number_students, summary_total_school_budget, how='left', on=['school_name'])
school_summary_df2 = school_summary_df2.rename(columns={"size": "Total Students"})
school_summary_df2 = school_summary_df2.rename(columns={"budget": "Total School Budget"})
school_summary_df2
# Out:
#                        Total Students  Total School Budget
# school_name
# Bailey High School               4976            3124928.0
# Cabrera High School              1858            1081356.0
# Figueroa High School             2949            1884411.0
# Ford High School                 2739            1763916.0
# Griffin High School              1468             917500.0
# Hernandez High School            4635            3022020.0
# Holden High School                427             248087.0
# Huang High School                2917            1910635.0
# Johnson High School              4761            3094650.0
# Pena High School                  962             585858.0
# Rodriguez High School            3999            2547363.0
# Shelton High School              1761            1056600.0
# Thomas High School               1635            1043130.0
# Wilson High School               2283            1319574.0
# Wright High School               1800            1049400.0

# %%
#Summarize the Per Student Budget -  - EXPLORING PANDAS ACTIVITY IN SUPPLEMENTAL PANDAS 
# per student budget = total school budget / school size
budget_per_student = summary_total_school_budget / summary_total_number_students
budget_per_student
# Out:
# school_name
# Bailey High School       628.0
# Cabrera High School      582.0
# Figueroa High School     639.0
# Ford High School         644.0
# Griffin High School      625.0
# Hernandez High School    652.0
# Holden High School       581.0
# Huang High School        655.0
# Johnson High School      650.0
# Pena High School         609.0
# Rodriguez High School    637.0
# Shelton High School      600.0
# Thomas High School       638.0
# Wilson High School       578.0
# Wright High School       583.0
# dtype: float64

# %%
#Average Math Score
summary_avg_math_score = school_data_combined_df.groupby(['school_name']).mean()['math_score']
summary_avg_math_score
# Out:
# school_name
# Bailey High School       77.048432
# Cabrera High School      83.061895
# Figueroa High School     76.711767
# Ford High School         77.102592
# Griffin High School      83.351499
# Hernandez High School    77.289752
# Holden High School       83.803279
# Huang High School        76.629414
# Johnson High School      77.072464
# Pena High School         83.839917
# Rodriguez High School    76.842711
# Shelton High School      83.359455
# Thomas High School       83.418349
# Wilson High School       83.274201
# Wright High School       83.682222
# Name: math_score, dtype: float64

# %%
#Average Reading Score
summary_avg_reading_score = school_data_combined_df.groupby(['school_name']).mean()['reading_score']
summary_avg_reading_score
# Out:
# school_name
# Bailey High School       81.033963
# Cabrera High School      83.975780
# Figueroa High School     81.158020
# Ford High School         80.746258
# Griffin High School      83.816757
# Hernandez High School    80.934412
# Holden High School       83.814988
# Huang High School        81.182722
# Johnson High School      80.966394
# Pena High School         84.044699
# Rodriguez High School    80.744686
# Shelton High School      83.725724
# Thomas High School       83.848930
# Wilson High School       83.989488
# Wright High School       83.955000
# Name: reading_score, dtype: float64

# %%
# Have to combine the two data sets into a single dataset to do the math
school_summary_df2 = pd.merge(summary_avg_math_score, summary_avg_reading_score, how='left', on=['school_name'])
school_summary_df2 = school_summary_df2.rename(columns={"math_score": "Average Math Score"})
school_summary_df2 = school_summary_df2.rename(columns={"reading_score": "Average Reading Score"})
school_summary_df2
# Out:
#                        Average Math Score  Average Reading Score
# school_name
# Bailey High School              77.048432              81.033963
# Cabrera High School             83.061895              83.975780
# Figueroa High School            76.711767              81.158020
# Ford High School                77.102592              80.746258
# Griffin High School             83.351499              83.816757
# Hernandez High School           77.289752              80.934412
# Holden High School              83.803279              83.814988
# Huang High School               76.629414              81.182722
# Johnson High School             77.072464              80.966394
# Pena High School                83.839917              84.044699
# Rodriguez High School           76.842711              80.744686
# Shelton High School             83.359455              83.725724
# Thomas High School              83.418349              83.848930
# ...

# %%
#% Passing Math 
summary_passing_math = school_data_combined_df[school_data_combined_df["math_score"] >= 70]
per_school_passing_math = summary_passing_math.groupby(["school_name"]).count()['student_name']
per_summary_passing_math = (per_school_passing_math/summary_total_number_students)*100
summary_passing_math.head()
# Out:
#    index  Student ID   student_name gender grade        school_name  \
# 0      0           0   Paul Bradley      M   9th  Huang High School
# 4      4           4     Bonnie Ray      F   9th  Huang High School
# 5      5           5  Bryan Miranda      M   9th  Huang High School
# 6      6           6  Sheena Carter      F  11th  Huang High School
# 8      8           8   Michael Roth      M  10th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635
# 5             94          94          0  District  2917  1910635
# 6             82          80          0  District  2917  1910635
# 8             95          87          0  District  2917  1910635

# %%
#% Passing Reading
summary_passing_reading = school_data_combined_df[school_data_combined_df["reading_score"] >= 70]
per_school_passing_reading = summary_passing_reading.groupby(["school_name"]).count()['student_name']
per_summary_passing_reading = (per_school_passing_reading/summary_total_number_students)*100
summary_passing_reading.head()
# Out:
#    index  Student ID     student_name gender grade        school_name  \
# 1      1           1     Victor Smith      M  12th  Huang High School
# 2      2           2  Kevin Rodriguez      M  12th  Huang High School
# 4      4           4       Bonnie Ray      F   9th  Huang High School
# 5      5           5    Bryan Miranda      M   9th  Huang High School
# 6      6           6    Sheena Carter      F  11th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635
# 5             94          94          0  District  2917  1910635
# 6             82          80          0  District  2917  1910635

# %%
# % Overall Passing Rate (Average of the above two)
#overall_passing_rate = (avg_math_score + avg_reading_score)/2
#overall_passing_rate

school_summary_df2["%Overall Passing Rate"] = (summary_avg_math_score + summary_avg_reading_score)/2
school_summary_df2.head()
# Out:
#                       Average Math Score  Average Reading Score  \
# school_name
# Bailey High School             77.048432              81.033963
# Cabrera High School            83.061895              83.975780
# Figueroa High School           76.711767              81.158020
# Ford High School               77.102592              80.746258
# Griffin High School            83.351499              83.816757
#
#                       %Overall Passing Rate
# school_name
# Bailey High School                79.041198
# Cabrera High School               83.518837
# Figueroa High School              78.934893
# Ford High School                  78.924425
# Griffin High School               83.584128

# %%
# Create a dataframe to hold the above results 
#  * School Name
#  * School Type
#  * Total Students
#  * Total School Budget
#  * Per Student Budget
#  * Average Math Score
#  * Average Reading Score
#  * % Passing Math
#  * % Passing Reading
#  * Overall Passing Rate (Average of the above two)  

# Drop all rows with missing information
#df = df.dropna(how='any')

# %%
#RENAME THE SCHOOL Name GROUPED LIST - ATTEMPTING TO TRY AND DELETE THE DUPLICATE SCHOOL NAMES FROM THE SCHOOL SUMMARY
#https://stackoverflow.com/questions/13035764/remove-rows-with-duplicate-indices-pandas-dataframe-and-timeseries/13036848#13036848
#school_name = np.unique(school_summary_df2.index.values, return_index = True )[0]
#school_summary_df2 = school_summary_df2.iloc[school_name]
#school_summary_df2
#school_summary_df2 = school_summary_df2.loc[~school_summary_df2.index.duplicated(keep='first')]
#school_summary_df2.head

# %%
#### ATTN: TA I'VE TRIED TO GET THIS TO JUST PRINT WITH NO AVAIL DUE TO THE NON NULL/NAN & I'VE ASKED ABOUT THIS IN THE CHAT AND NO LUCK
#Organize and rename columns & Create a dataframe to hold the above results
school_summary_df2 = pd.DataFrame({"School Name":[grouped_school_data],
    "School Type":[summary_school_type],
    "Total Students": f"{summary_total_number_students}",
    "Total School Budget": f"${summary_total_school_budget}",
    "Per Student Budget": f"${budget_per_student}",
    "Average Math Score": f"{summary_avg_math_score}",
    "Average Reading Score":f"{summary_avg_reading_score}",
    "% Passing Math": f"{summary_passing_math}%",
    "% Passing Reading": f"{summary_passing_reading}%",
    "Overall Passing Rate": f"{overall_passing_rate}%"
}) 
school_summary_df2
# Out:
#                                          School Name  \
# 0                school_name      type  Student I...
#
#                                          School Type  \
# 0                                  Student ID
# sch...
#
#                                       Total Students  \
# 0  school_name\nBailey High School       4976\nCa...
#
#                                  Total School Budget  \
# 0  $school_name\nBailey High School       3124928...
#
#                                   Per Student Budget  \
# 0  $school_name\nBailey High School       628.0\n...
#
#                                   Average Math Score  \
# 0  school_name\nBailey High School       77.04843...
#
#                                Average Reading Score  \
# 0  school_name\nBailey High School       81.03396...
#
#                                       % Passing Math  \
# 0         index  Student ID     student_name gend...
#
#                                    % Passing Reading Overall Passing Rate
# ...

# %%
##https://stackoverflow.com/questions/27719407/pandas-concat-valueerror-shape-of-passed-values-is-blah-indices-imply-blah2
#df1.reset_index(drop=True, inplace=True)
#df2.reset_index(drop=True, inplace=True)
#df = pd.concat([df1, df2], axis=1)
#District_Summary.reset_index(drop=True, inplace=True)
#school_summary_df2.reset_index(drop=True, inplace=True)
#df = pd.concat([District_Summary, school_summary_df2], axis=1)

# %%
## RESOURCES I USED IN AN ATTEMPT TO TRY AND MAKE THE DUPLICATES GO AWAY 
#https://stackoverflow.com/questions/42324077/how-can-i-get-pandas-groupby-command-to-return-a-dataframe-instead-of-a-series
#df6 = df0.groupby(['city','state'])['pop'].sum().reset_index()/// or df6 = df0.groupby(['city','state'], as_index=False)['pop'].sum()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-118-285edede8f2b> in <module>
#       2 #https://stackoverflow.com/questions/42324077/how-can-i-get-pandas-groupby-command-to-return-a-dataframe-instead-of-a-series
#       3 #df6 = df0.groupby(['city','state'])['pop'].sum().reset_index()/// or df6 = df0.groupby(['city','state'], as_index=False)['pop'].sum()
# ----> 4 school_summary_df2 = pd.DataFrame({"School Type" :summary_school_type})
#       5 school_summary_df2
#       6 #    "Total Students": summary_total_number_students,
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
# ...

# %% [markdown]
# ## Top Performing Schools (By Passing Rate)

# %% [markdown]
# * Sort and display the top five schools in overall passing rate

# %%
# Sort and display the top five schools in overall passing rate
# Sort results in descending order
# merged_df = merged_df.sort_values(["% Recommend"], ascending=False).round(2) & print head for the top 5
top_five_perfoming_schools = school_summary_df2.sort_values(["Overall Passing Rate"], ascending=True).round(2)
top_five_perfoming_schools.head(5)
# Out:
#                                          School Name  \
# 0                school_name      type  Student I...
#
#                                          School Type  \
# 0                                  Student ID
# sch...
#
#                                       Total Students  \
# 0  school_name\nBailey High School       4976\nCa...
#
#                                  Total School Budget  \
# 0  $school_name\nBailey High School       3124928...
#
#                                   Per Student Budget  \
# 0  $school_name\nBailey High School       628.0\n...
#
#                                   Average Math Score  \
# 0  school_name\nBailey High School       77.04843...
#
#                                Average Reading Score  \
# 0  school_name\nBailey High School       81.03396...
#
#                                       % Passing Math  \
# 0         index  Student ID     student_name gend...
#
#                                    % Passing Reading Overall Passing Rate
# ...

# %% [markdown]
# ## Bottom Performing Schools (By Passing Rate)

# %% [markdown]
# * Sort and display the five worst-performing schools

# %%
# Sort results in descending order
# Sort and display the top five schools in overall passing rate
# merged_df = merged_df.sort_values(["% Recommend"], ascending=True).round(2) & print tail() for the last 5 
worst_five_perfoming_schools = school_summary_df2.sort_values(["Overall Passing Rate"], ascending=False).round(2)
worst_five_perfoming_schools.tail(5)
# Out:
#                                          School Name  \
# 0                school_name      type  Student I...
#
#                                          School Type  \
# 0                                  Student ID
# sch...
#
#                                       Total Students  \
# 0  school_name\nBailey High School       4976\nCa...
#
#                                  Total School Budget  \
# 0  $school_name\nBailey High School       3124928...
#
#                                   Per Student Budget  \
# 0  $school_name\nBailey High School       628.0\n...
#
#                                   Average Math Score  \
# 0  school_name\nBailey High School       77.04843...
#
#                                Average Reading Score  \
# 0  school_name\nBailey High School       81.03396...
#
#                                       % Passing Math  \
# 0         index  Student ID     student_name gend...
#
#                                    % Passing Reading Overall Passing Rate
# ...

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
#* Create a table that lists the average MATH Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#Series for each grade level & grade math scores - 9th, 10th, 11th, & 12th grade 
#bootcamp_name.reset_index(inplace=True)
#bootcamp_name.columns = ["BootcampName", "Count"]

#school_math_grades.columns = ["school_name", "grade", "math_score"]
total_combined_grades = school_data_combined_df.groupby(['grade', 'school_name']).mean()['math_score']
school_math_grades_final = pd.DataFrame(total_combined_grades)
school_math_grades_final
# Out:
#                              math_score
# grade school_name
# 10th  Bailey High School      76.996772
#       Cabrera High School     83.154506
#       Figueroa High School    76.539974
#       Ford High School        77.672316
#       Griffin High School     84.229064
#       Hernandez High School   77.337408
#       Holden High School      83.429825
#       Huang High School       75.908735
#       Johnson High School     76.691117
#       Pena High School        83.372000
#       Rodriguez High School   76.612500
#       Shelton High School     82.917411
#       Thomas High School      83.087886
#       Wilson High School      83.724422
#       Wright High School      84.010288
# 11th  Bailey High School      77.515588
#       Cabrera High School     82.765560
#       Figueroa High School    76.884344
#       Ford High School        76.918058
#       Griffin High School     83.842105
#       Hernandez High School   77.136029
#       Holden High School      85.000000
# ...

# %%
#Group each series by school - 9th, 10th, 11th, & 12th grade 

school_level_math_grades = school_data_combined_df.groupby(['school_name', 'grade']).mean()['math_score']
school_level_math_grades_df = pd.DataFrame(school_level_math_grades)
school_level_math_grades
# Out:
# school_name            grade
# Bailey High School     10th     76.996772
#                        11th     77.515588
#                        12th     76.492218
#                        9th      77.083676
# Cabrera High School    10th     83.154506
#                        11th     82.765560
#                        12th     83.277487
#                        9th      83.094697
# Figueroa High School   10th     76.539974
#                        11th     76.884344
#                        12th     77.151369
#                        9th      76.403037
# Ford High School       10th     77.672316
#                        11th     76.918058
#                        12th     76.179963
#                        9th      77.361345
# Griffin High School    10th     84.229064
#                        11th     83.842105
#                        12th     83.356164
#                        9th      82.044010
# Hernandez High School  10th     77.337408
#                        11th     77.136029
# ...

# %%
######### NOTE TO TA I STILL ATTEMPTED TO CREATE THE CODE EVEN THOUGH I WAS HAVING TROUBLE WITH MY SCHOOL SUMMARY 
######### THE CODE HAS BEEN COMMITED OUT DUE TO ERRORS
# Combine the series into a dataframe for each grade level at each school. NEED TO MERGE TWO DATAFRAME
avg_combined_math_grades_merged = pd.merge(school_math_grades_final, school_level_math_grades, how='left', on=["school_name", "math_score", "grade"])
combined_math_grades_byschool = avg_combined_math_grades_merged.groupby(['grade'].mean()['math_score']
avg_combined_math_grades_merged


### CREATE DATE FRAME WITH COLUMN NAMES - school_level_math_grades
#school_level_math_grades = pd.DataFrame(columns = ["9th", "10th", "11th", "12th"])
#school_math_grades_final = pd.DataFrame({"9th": school_math_grades,
#                                             "10th": school_math_grades,
#                                             "11th": school_math_grades,
#                                             "12th": school_math_grades})
#school_math_grades_final =
# Out:
#   File "<ipython-input-199-be7b2f76f1c4>", line 6
#     avg_combined_math_grades_merged
#                                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
#* Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.

school_read_grades = school_data_combined_df.groupby(['grade', 'school_name']).mean()['reading_score']
school_read_grades_final = pd.DataFrame(school_read_grades)
school_read_grades
# Out:
# grade  school_name
# 10th   Bailey High School       80.907183
#        Cabrera High School      84.253219
#        Figueroa High School     81.408912
#        Ford High School         81.262712
#        Griffin High School      83.706897
#        Hernandez High School    80.660147
#        Holden High School       83.324561
#        Huang High School        81.512386
#        Johnson High School      80.773431
#        Pena High School         83.612000
#        Rodriguez High School    80.629808
#        Shelton High School      83.441964
#        Thomas High School       84.254157
#        Wilson High School       84.021452
#        Wright High School       83.812757
# 11th   Bailey High School       80.945643
#        Cabrera High School      83.788382
#        Figueroa High School     80.640339
#        Ford High School         80.403642
#        Griffin High School      84.288089
#        Hernandez High School    81.396140
#        Holden High School       83.815534
# ...

# %%
#Group each series by school - 9th, 10th, 11th, & 12th grade 
school_level_reading_grades = round(school_data_combined_df.groupby(['school_name', 'grade']).mean()['reading_score'],2)
school_level_reading_grades
# Out:
# school_name            grade
# Bailey High School     10th     80.91
#                        11th     80.95
#                        12th     80.91
#                        9th      81.30
# Cabrera High School    10th     84.25
#                        11th     83.79
#                        12th     84.29
#                        9th      83.68
# Figueroa High School   10th     81.41
#                        11th     80.64
#                        12th     81.38
#                        9th      81.20
# Ford High School       10th     81.26
#                        11th     80.40
#                        12th     80.66
#                        9th      80.63
# Griffin High School    10th     83.71
#                        11th     84.29
#                        12th     84.01
#                        9th      83.37
# Hernandez High School  10th     80.66
#                        11th     81.40
#                        12th     80.86
#                        9th      80.87
# ...

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
# Sample bins. Feel free to create your own bins. - EXPLORING PANDAS ACTIVITY IN SUPPLEMENTAL PANDAS 
spending_bins = [0, 585, 615, 645, 675]
group_names = ["<$585", "$585-615", "$615-645", "$645-675"]

# %%
# 1st cut() the dataframe column you'd like to bin
#pd.cut(vehicles_df["Horsepower"], hp_bins, labels=hp_labels)
#vehicles_df["Speed"] = pd.cut(vehicles_df["Horsepower"], hp_bins, labels=hp_labels)
#vehicles_df(
school_summary_df2["Scores by School Spending"] = pd.cut(school_summary_df2["Total Students"], spending_bins, labels = group_names)
school_summary_df2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-203-8dfe13127de5> in <module>
#       3 #vehicles_df["Speed"] = pd.cut(vehicles_df["Horsepower"], hp_bins, labels=hp_labels)
#       4 #vehicles_df(
# ----> 5 school_summary_df2["Scores by School Spending"] = pd.cut(school_summary_df2["Total Students"], spending_bins, labels = group_names)
#       6 school_summary_df2
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/reshape/tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     263         include_lowest=include_lowest,
#     264         dtype=dtype,
# --> 265         duplicates=duplicates,
#     266     )
#     267
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/reshape/tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates)
#     386
# ...

# %%
# Creare the breakdowns for the date below

# Average Math Score School Spending - Breakdown by each school spending average

# Average Reading Score School Spending - Breakdown by each school spending average

# % Passing Math School Spending - Breakdown by each school spending average

# % Passing Reading School Spending - Breakdown by each school spending average

# Overall Passing Rate School Spending - Breakdown by each school spending average

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# Sample bins. Feel free to create your own bins.
size_bins = [0, 1000, 2000, 5000]
group_names = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type.
